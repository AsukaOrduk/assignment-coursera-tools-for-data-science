# %% [markdown]
# Data Science Tools

# %% [markdown]
# Here will be introduction

# %% [markdown]
# - Python
# - R
# - Julia
# - SQL
# - C++
# - Scala
# - Java
# - JavaScript

# %% [markdown]
# - Pandas
# - NumPy
# - TensorFlow
# - Matplotlib
# - Scikit-learn

# %% [markdown]
# ## Data Science Tools
#
#  Tool          Purpose
#
#  Jupyter       Interactive coding
#  RStudio       R programming environment
#  Tableau       Data visualization
#  Apache Spark  Big data processing
#  Git           Version control

# %% [markdown]
# ## Arithmetic Expression Examples
# The following examples illustrate basic arithmetic operations.

# %%
a = 5
b = 10
multiplication_result = a * b
addition_result = a + b
multiplication_result, addition_result
# Out:
# (50, 15)

# %%
def convert_minutes_to_hours(minutes):
    hours = minutes / 60
    return hours


convert_minutes_to_hours(60)
# Out:
# 1.0

# %% [markdown]
# ## Objectives
# - understand basics of data science
# - understand how is arithmetic operations working
# - understand basics of python

# %% [markdown]
# Name:
# Afanasev Artur

# %%
https://github.com/AsukaOrduk/assignment-coursera-tools-for-data-science

# %% [markdown]
# ![image.png](attachment:050182a3-5edf-40b4-aa3e-3efabbc871a3.png)
