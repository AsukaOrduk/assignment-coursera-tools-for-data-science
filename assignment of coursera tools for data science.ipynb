# %% [markdown]
# Data Science Tools

# %% [markdown]
# Here will be introduction

# %% [markdown]
# - Python
# - R
# - SQL
# - Scala
# - C++
# - Javascript
# - Visual basic
# - Julia
# - PHP
# - Go
# - Ruby
# - Javacript

# %% [markdown]
# - NumPy
# - Pandas
# - Matplotlib
# - Seaborn
# - Scikit-learn
# - SciPy
# - TensorFlow
# - Keras
# - PyTorch
# - Statsmodels
# - NLTK
# - spaCy
# - Plotly
# - Bokeh
# - Dask
# - XGBoost
# - LightGBM
# - OpenCV

# %% [markdown]
# | **Data Science Tools**          |
# |-------------------|
# | Pandas            |
# | Numpy             |
# | Matplotlib        |
# | Seaborn           |
# | Scikit-learn      |
# | Keras             |
# | TensorFlow        |
# | PyTorch           |
# | Apache Spark      |
# | Vegas             |
# | Big DL            |
# | Ggplot2           |
#      |

# %% [markdown]
# ## Arithmetic Expression Examples

# %%
a = 5
b = 10
multiplication_result = a * b
addition_result = a + b
multiplication_result, addition_result
# Out:
# (50, 15)

# %%
def convert_minutes_to_hours(minutes):
    hours = minutes / 60
    return hours


convert_minutes_to_hours(60)
# Out:
# 1.0

# %% [markdown]
# ## Objectives
# - understand basics of data science
# - understand how is arithmetic operations working
# - understand basics of python

# %% [markdown]
# ## Author (s):
# Afanasev Artur

# %%
https://github.com/AsukaOrduk/assignment-coursera-tools-for-data-science

# %% [markdown]
# ![Снимок экрана 2024-10-19 113356.png](attachment:b859159a-002c-40c6-aef1-7852d4b623db.png)
